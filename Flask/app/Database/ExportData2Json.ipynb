# %%
import pymysql
import json
# database connection AWS cloud database
db = pymysql.connect("umdsummer.c6uvxtdq5jdq.us-east-2.rds.amazonaws.com","root","UMDSummer2021","QA" )

# %%
Question_id = 1
edit_times = 3

# %%
cursor = db.cursor()
cursor.execute("select * from Question where Question_id = " +
               str(Question_id)+" and edit_times = "+str(edit_times)+";")
columns = cursor.description
NewQuestion = [{columns[index][0]:column for index,
                column in enumerate(value)} for value in cursor.fetchall()]
json_Question = {}
for i in NewQuestion:
    json_Question["Question_id"] = NewQuestion[0]['Question_id']
    json_Question["edit_times"] = NewQuestion[0]['edit_times']
    json_Question["Timestamp_frontend"] = str(
        NewQuestion[0]['Timestamp_frontend'])
    json_Question["Timestamp_backend"] = str(
        NewQuestion[0]['Timestamp_backend'])
    json_Question["Username"] = NewQuestion[0]['Username']
    json_Question["Answer"] = NewQuestion[0]['Answer']
    json_Question["LevenshteinDistance"] = NewQuestion[0]['LevenshteinDistance']
    json_Question["NewQuestion"] = NewQuestion[0]['Question']
if edit_times > 1:
    cursor.execute("select * from Question where Question_id = " +
                   str(Question_id)+" and edit_times = "+str(edit_times-1)+";")
    columns = cursor.description
    OldQuestion = [{columns[index][0]:column for index,
                    column in enumerate(value)} for value in cursor.fetchall()]
    for i in OldQuestion:
        json_Question["OldQuestion"] = OldQuestion[0]['Question']
json_data = json_Question

# buzzer
cursor.execute("select * from Buzzer where Question_id = " +
               str(Question_id)+" and edit_times = "+str(edit_times)+";")
columns = cursor.description
NewBuzz = [{columns[index][0]:column for index,
            column in enumerate(value)} for value in cursor.fetchall()]
json_Buzzer = {}
json_Buzzer["Question_id"] = NewBuzz[0]['Question_id']
json_Buzzer["edit_times"] = NewBuzz[0]['edit_times']
json_Buzzer["Timestamp_frontend"] = str(NewBuzz[0]['Timestamp_frontend'])
json_Buzzer["Timestamp_backend"] = str(NewBuzz[0]['Timestamp_backend'])
json_Buzzer["new_buzz_pos"] = NewBuzz[0]['Buzz_pos']
json_Buzzer["new_importance"] = NewBuzz[0]['importance']
if edit_times > 1:
    cursor.execute("select * from Buzzer where Question_id = " +
                   str(Question_id)+" and edit_times = "+str(edit_times-1)+";")
    columns = cursor.description
    OldBuzz = [{columns[index][0]:column for index,
                column in enumerate(value)} for value in cursor.fetchall()]
    for i in OldBuzz:
        json_Buzzer["old_buzz_pos"] = OldBuzz[0]['Buzz_pos']
        json_Buzzer["old_importance"] = OldBuzz[0]['importance']
json_data["buzz"] = json_Buzzer

# country
cursor.execute(
    "select * from CountryRepresent where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times)+";")
columns = cursor.description
NewCountry = [{columns[index][0]:column for index,
            column in enumerate(value)} for value in cursor.fetchall()]
json_Country = {}
json_Country["Question_id"] = NewCountry[0]["Question_id"]
json_Country["edit_times"] = NewCountry[0]["edit_times"]
json_Country["Timestamp_frontend"] = str(NewCountry[0]["Timestamp_frontend"])
json_Country["Timestamp_backend"] = str(NewCountry[0]["Timestamp_backend"])
json_Country["New_Over_represented_Countries"] = NewCountry[0]["Over_represented_Countries"]
json_Country["New_Under_represented_Countries"] = NewCountry[0]["Under_represented_Countries"]
if edit_times > 1:
    cursor.execute(
        "select * from CountryRepresent where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times-1)+";")
    columns = cursor.description
    OldCountry = [{columns[index][0]:column for index,
                column in enumerate(value)} for value in cursor.fetchall()]
    for i in OldCountry:
        json_Country["Old_Over_represented_Countries"] = OldCountry[0]["Over_represented_Countries"]
        json_Country["Old_Under_represented_Countries"] = OldCountry[0]["Under_represented_Countries"]
json_data["country"] = json_Country

# Difficulty
cursor.execute(
    "select * from Difficulty where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times)+";")
columns = cursor.description
NewDifficulty = [{columns[index][0]:column for index,
            column in enumerate(value)} for value in cursor.fetchall()]
json_difficulty = {}
json_difficulty["Question_id"] = NewDifficulty[0]["Question_id"]
json_difficulty["edit_times"] = NewDifficulty[0]["edit_times"]
json_difficulty["Timestamp_frontend"] = str(NewDifficulty[0]["Timestamp_frontend"])
json_difficulty["Timestamp_backend"] = str(NewDifficulty[0]["Timestamp_backend"])
json_difficulty["NewDifficulty"] = NewDifficulty[0]["Difficulty"]
if edit_times > 1:
    cursor.execute(
    "select * from Difficulty where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times-1)+";")
    columns = cursor.description
    OldDifficulty = [{columns[index][0]:column for index,
                column in enumerate(value)} for value in cursor.fetchall()]
    json_difficulty["OldDifficulty"] = OldDifficulty[0]["Difficulty"]
json_data["difficulty"] = json_difficulty

# Genre
cursor.execute(
    "select * from Genre where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times)+";")
columns = cursor.description
NewGenre = [{columns[index][0]:column for index,
            column in enumerate(value)} for value in cursor.fetchall()]
json_genre = {}
json_genre["Question_id"] = NewGenre[0]["Question_id"]
json_genre["edit_times"] = NewGenre[0]["edit_times"]
json_genre["Timestamp_frontend"] = str(NewGenre[0]["Timestamp_frontend"])
json_genre["Timestamp_backend"] = str(NewGenre[0]["Timestamp_backend"])
json_genre["NewGenre"] = NewGenre[0]["Genre"]
if edit_times > 1:
    cursor.execute(
    "select * from Genre where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times-1)+";")
    columns = cursor.description
    OldGenre = [{columns[index][0]:column for index,
                column in enumerate(value)} for value in cursor.fetchall()]
    json_genre["OldGenre"] = OldGenre[0]["Genre"]
json_data["genre"] = json_genre

# machineguesses
cursor.execute(
    "select * from MachineGuesses where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times)+";")
columns = cursor.description
NewGenre = [{columns[index][0]:column for index,
            column in enumerate(value)} for value in cursor.fetchall()]
json_machineguesses = {}
json_machineguesses["Question_id"] = NewGenre[0]["Question_id"]
json_machineguesses["edit_times"] = NewGenre[0]["edit_times"]
json_machineguesses["Timestamp_frontend"] = str(NewGenre[0]["Timestamp_frontend"])
json_machineguesses["Timestamp_backend"] = str(NewGenre[0]["Timestamp_backend"])
json_machineguesses["NewMachineGuesses"] = NewGenre[0]["MachineGuesses"]
if edit_times > 1:
    cursor.execute(
    "select * from MachineGuesses where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times-1)+";")
    columns = cursor.description
    OldGenre = [{columns[index][0]:column for index,
                column in enumerate(value)} for value in cursor.fetchall()]
    json_machineguesses["OldMachineGuesses"] = OldGenre[0]["MachineGuesses"]
json_data["machineguesses"] = json_machineguesses

# similarquestions
cursor.execute(
    "select * from Similarquestions where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times)+";")
columns = cursor.description
NewSimilarquestions = [{columns[index][0]:column for index,
            column in enumerate(value)} for value in cursor.fetchall()]
json_similarquestions = {}
json_similarquestions["Question_id"] = NewSimilarquestions[0]["Question_id"]
json_similarquestions["edit_times"] = NewSimilarquestions[0]["edit_times"]
json_similarquestions["Timestamp_frontend"] = str(NewSimilarquestions[0]["Timestamp_frontend"])
json_similarquestions["Timestamp_backend"] = str(NewSimilarquestions[0]["Timestamp_backend"])
json_similarquestions["NewSimilarQuestions"] = NewSimilarquestions[0]["SimilarQuestions"]
if edit_times > 1:
    cursor.execute(
    "select * from Similarquestions where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times-1)+";")
    columns = cursor.description
    OldSimilarquestions = [{columns[index][0]:column for index,
                column in enumerate(value)} for value in cursor.fetchall()]
    json_similarquestions["OldSimilarQuestions"] = OldSimilarquestions[0]["SimilarQuestions"]
json_data["similarquestions"] = json_similarquestions

# Pronunciation
cursor.execute(
    "select * from Pronunciation where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times)+";")
columns = cursor.description
NewPronunciation = [{columns[index][0]:column for index,
            column in enumerate(value)} for value in cursor.fetchall()]
json_pronunciation = {}
json_pronunciation["Question_id"] = NewPronunciation[0]["Question_id"]
json_pronunciation["edit_times"] = NewPronunciation[0]["edit_times"]
json_pronunciation["Timestamp_frontend"] = str(NewPronunciation[0]["Timestamp_frontend"])
json_pronunciation["Timestamp_backend"] = str(NewPronunciation[0]["Timestamp_backend"])
json_pronunciation["New_With_Pron_guide"] = NewPronunciation[0]["With_Pron_guide"]
json_pronunciation["New_Without_Pron_guide"] = NewPronunciation[0]["Without_Pron_guide"]
if edit_times > 1:
    cursor.execute(
    "select * from Pronunciation where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times-1)+";")
    columns = cursor.description
    OldPronunciation = [{columns[index][0]:column for index,
                column in enumerate(value)} for value in cursor.fetchall()]
    json_pronunciation["Old_With_Pron_guide"] = OldPronunciation[0]["With_Pron_guide"]
    json_pronunciation["Old_Without_Pron_guide"] = OldPronunciation[0]["Without_Pron_guide"]
json_data["pronunciation"] = json_pronunciation

json_pre = json.dumps(json_data)
f = open('data.json', 'w')
f.write(json_pre)
f.close()

# %%
Question_id = 1
edit_times = 3
cursor = db.cursor()
cursor.execute(
    "select * from Pronunciation where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times)+";")
columns = cursor.description
NewPronunciation = [{columns[index][0]:column for index,
            column in enumerate(value)} for value in cursor.fetchall()]
json_pronunciation = {}
json_pronunciation["Question_id"] = NewPronunciation[0]["Question_id"]
json_pronunciation["edit_times"] = NewPronunciation[0]["edit_times"]
json_pronunciation["Timestamp_frontend"] = str(NewPronunciation[0]["Timestamp_frontend"])
json_pronunciation["Timestamp_backend"] = str(NewPronunciation[0]["Timestamp_backend"])
json_pronunciation["New_With_Pron_guide"] = NewPronunciation[0]["With_Pron_guide"]
json_pronunciation["New_Without_Pron_guide"] = NewPronunciation[0]["Without_Pron_guide"]
if edit_times > 1:
    cursor.execute(
    "select * from Pronunciation where Question_id = "+str(Question_id)+" and edit_times = "+str(edit_times-1)+";")
    columns = cursor.description
    OldPronunciation = [{columns[index][0]:column for index,
                column in enumerate(value)} for value in cursor.fetchall()]
    json_pronunciation["Old_With_Pron_guide"] = OldPronunciation[0]["With_Pron_guide"]
    json_pronunciation["Old_Without_Pron_guide"] = OldPronunciation[0]["Without_Pron_guide"]
json_data["pronunciation"] = json_pronunciation
print(json_pronunciation)
# Out:
# {'Question_id': 1, 'edit_times': 3, 'Timestamp_frontend': '2021-08-19 12:22:57', 'Timestamp_backend': '2021-08-19 12:22:57', 'New_With_Pron_guide': '{"word1": "guide1", "word2": "guide2"}', 'New_Without_Pron_guide': '{"word1": "", "word2": "", "word3": ""}', 'Old_With_Pron_guide': '{"word1": "guide1", "word2": "guide2"}', 'Old_Without_Pron_guide': '{"word1": "", "word2": "", "word3": ""}'}

# %%
db.close()

# %%
import json
with open("./test.json", 'r') as load_f:
    load_dict = json.load(load_f)
    print(type(load_dict))
for i in load_dict["data"]:
    print(i)
    print(load_dict["data"][i]["Question"])
    load_dict["data"][i]["Question"] = re.sub(r'\'', '\"', load_dict["data"][i]["Question"])
print(load_dict)
# Out:
# <class 'dict'>
# 08/20/2021, 09:17:01
# This man was inspired by the work of Toru Takemitsu
# 08/20/2021, 09:17:36
# This man was inspired by the work of Toru Takemitsu while staying in Japan and conducted the premiere of
# 08/20/2021, 09:18:41
# This man was inspired by the work of Toru Takemitsu while staying in Japan and conducted the premiere of Takemitsu's Dorian Horizon. This man formed a friendship with
# 08/20/2021, 09:19:17
# This man was inspired by the work of Toru Takemitsu while staying in Japan and conducted the premiere of Takemitsu's Dorian Horizon. This man formed a friendship with the Mexican Composer Carlos Chávez to whom his second symphony The Short Symphony is dedicated.
# 08/20/2021, 09:23:59
# ...

# %%
str = "I\"m Janicestr "

# %%
import re
re.sub(r'\"[A-Za-z]', '\'', str)
# Out:
# "I' Janicestr "

# %%
def print_dict(k, v):
    if isinstance(v, dict):
        for kk in v.keys():
            print_dict(kk, v[kk])
    else:
        if isinstance(v, type(str)) :
            v = re.sub(r'\'', '', v)

import json
with open("./test.json", 'r') as load_f:
    load_dict = json.load(load_f)

for k in load_dict.keys():
    print_dict(k, load_dict[k])
print(load_dict)
# Out:
# {'q_id': 'aQZ29SmTmNNNl8h0PzFJrNew7ms2', 'UID': 1, 'data': {'08/20/2021, 09:17:01': {'Question': 'This man was inspired by the work of Toru Takemitsu', 'Answer': 'Aaron_Copland', 'Relevant': 'First Time Stamp'}, '08/20/2021, 09:17:36': {'Question': 'This man was inspired by the work of Toru Takemitsu while staying in Japan and conducted the premiere of ', 'Answer': 'Aaron_Copland', 'add': ['Japan', 'and', 'conducted', 'the', 'premiere', 'of'], 'remove': ['Japan.'], 'Relevant': '7 words need to be added, deleted or replaced between diff  '}, '08/20/2021, 09:18:41': {'Question': "This man was inspired by the work of Toru Takemitsu while staying in Japan and conducted the premiere of Takemitsu's Dorian Horizon. This man formed a friendship with ", 'Answer': 'Aaron_Copland', 'add': ['This', 'man', 'formed', 'a', 'friendship', 'with'], 'remove': [], 'Relevant': '6 words need to be added, deleted or replaced between diff  '}, '08/20/2021, 09:19:17': {'Question': "This man was inspired by t
# ...
